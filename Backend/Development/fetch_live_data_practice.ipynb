# %% [markdown]
# # Practice of fetching live data from the api
# Continuation of nba_api_fetch_practice.ipynb

# %%
from nba_api.live.nba.endpoints import scoreboard, boxscore
from datetime import datetime, timezone
from dateutil import parser
f = "{gameId}: {awayTeam} vs. {homeTeam} @ {gameTimeLTZ}"

board = scoreboard.ScoreBoard()
print("ScoreBoardDate: " + board.score_board_date)
games = board.games.get_dict()
for game in games:
    gameTimeLTZ = parser.parse(game["gameTimeUTC"]).replace(tzinfo=timezone.utc).astimezone(tz=None)
    print(f.format(gameId=game,awayTeam=game['awayTeam']['teamName'],homeTeam=game['homeTeam']['teamName'],gameTimeLTZ=gameTimeLTZ))
# Out:
# ScoreBoardDate: 2025-05-21
# {'gameId': '0042400301', 'gameCode': '20250521/INDNYK', 'gameStatus': 2, 'gameStatusText': 'Q4 6:23', 'period': 4, 'gameClock': 'PT06M23.00S', 'gameTimeUTC': '2025-05-22T00:00:00Z', 'gameEt': '2025-05-21T20:00:00-04:00', 'regulationPeriods': 4, 'ifNecessary': False, 'seriesGameNumber': 'Game 1', 'gameLabel': 'East Conf. Finals', 'gameSubLabel': 'Game 1', 'seriesText': 'Series tied 0-0', 'seriesConference': 'East', 'poRoundDesc': 'Conf. Finals', 'gameSubtype': '', 'isNeutral': False, 'homeTeam': {'teamId': 1610612752, 'teamName': 'Knicks', 'teamCity': 'New York', 'teamTricode': 'NYK', 'wins': 0, 'losses': 0, 'score': 111, 'seed': 3, 'inBonus': '0', 'timeoutsRemaining': 3, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 36}, {'period': 2, 'periodType': 'REGULAR', 'score': 33}, {'period': 3, 'periodType': 'REGULAR', 'score': 21}, {'period': 4, 'periodType': 'REGULAR', 'score': 21}]}, 'awayTeam': {'teamId': 1610612754, 'teamName': 'Pacers', 'teamCity': 'Indiana', 'teamTricode': 'IND', 'wins': 0, 'losses': 0, 'score': 94, 'seed': 4, 'inBonus': '0', 'timeoutsRemaining': 1, 'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 34}, {'period': 2, 'periodType': 'REGULAR', 'score': 28}, {'period': 3, 'periodType': 'REGULAR', 'score': 25}, {'period': 4, 'periodType': 'REGULAR', 'score': 7}]}, 'gameLeaders': {'homeLeaders': {'personId': 1626157, 'name': 'Karl-Anthony Towns', 'jerseyNum': '32', 'position': 'CF', 'teamTricode': 'NYK', 'playerSlug': 'karl-anthony-towns', 'points': 28, 'rebounds': 9, 'assists': 2}, 'awayLeaders': {'personId': 1630169, 'name': 'Tyrese Haliburton', 'jerseyNum': '0', 'position': 'G', 'teamTricode': 'IND', 'playerSlug': 'tyrese-haliburton', 'points': 23, 'rebounds': 3, 'assists': 7}}, 'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}: Pacers vs. Knicks @ 2025-05-21 17:00:00-07:00

# %%
box = boxscore.BoxScore('0042400301')
box.game.get_dict()
# Out:
# {'gameId': '0042400301',
#  'gameTimeLocal': '2025-05-21T20:00:00-04:00',
#  'gameTimeUTC': '2025-05-22T00:00:00Z',
#  'gameTimeHome': '2025-05-21T20:00:00-04:00',
#  'gameTimeAway': '2025-05-21T20:00:00-04:00',
#  'gameEt': '2025-05-21T20:00:00-04:00',
#  'duration': 137,
#  'gameCode': '20250521/INDNYK',
#  'gameStatusText': 'Q4 6:23',
#  'gameStatus': 2,
#  'regulationPeriods': 4,
#  'period': 4,
#  'gameClock': 'PT06M23.00S',
#  'attendance': 0,
#  'sellout': '0',
#  'arena': {'arenaId': 30,
#   'arenaName': 'Madison Square Garden',
#   'arenaCity': 'New York',
#   'arenaState': 'NY',
#   'arenaCountry': 'US',
#   'arenaTimezone': 'America/New_York'},
#  'officials': [{'personId': 2534,
#    'name': 'Zach Zarba',
#    'nameI': 'Z. Zarba',
#    'firstName': 'Zach',
#    'familyName': 'Zarba',
#    'jerseyNum': '15',
#    'assignment': 'OFFICIAL1'},
#   {'personId': 101283,
#    'name': 'Brian Forte',
#    'nameI': 'B. Forte',
#    'firstName': 'Brian',
#    'familyName': 'Forte',
#    'jerseyNum': '45',
#    'assignment': 'ALTERNATE'},
#   {'personId': 202049,
#    'name': 'Ben Taylor',
#    'nameI': 'B. Taylor',
#    'firstName': 'Ben',
#    'familyName': 'Taylor',
#    'jerseyNum': '46',
#    'assignment': 'OFFICIAL2'},
#   {'personId': 203591,
#    'name': 'Mitchell Ervin',
#    'nameI': 'M. Ervin',
#    'firstName': 'Mitchell',
#    'familyName': 'Ervin',
#    'jerseyNum': '27',
#    'assignment': 'OFFICIAL3'}],
#  'homeTeam': {'teamId': 1610612752,
#   'teamName': 'Knicks',
#   'teamCity': 'New York',
#   'teamTricode': 'NYK',
#   'score': 111,
#   'inBonus': '0',
#   'timeoutsRemaining': 3,
#   'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 36},
#    {'period': 2, 'periodType': 'REGULAR', 'score': 33},
#    {'period': 3, 'periodType': 'REGULAR', 'score': 21},
#    {'period': 4, 'periodType': 'REGULAR', 'score': 21}],
#   'players': [{'status': 'ACTIVE',
#     'order': 1,
#     'personId': 1628384,
#     'jerseyNum': '8',
#     'position': 'SF',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 2,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 11,
#      'fieldGoalsMade': 5,
#      'fieldGoalsPercentage': 0.45454545454545503,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 73.0,
#      'minutes': 'PT30M10.01S',
#      'minutesCalculated': 'PT30M',
#      'plus': 81.0,
#      'plusMinusPoints': 8.0,
#      'points': 13,
#      'pointsFastBreak': 2,
#      'pointsInThePaint': 6,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 2,
#      'steals': 2,
#      'threePointersAttempted': 6,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.333333333333333,
#      'turnovers': 1,
#      'twoPointersAttempted': 5,
#      'twoPointersMade': 3,
#      'twoPointersPercentage': 0.6},
#     'name': 'OG Anunoby',
#     'nameI': 'O. Anunoby',
#     'firstName': 'OG',
#     'familyName': 'Anunoby'},
#    {'status': 'ACTIVE',
#     'order': 2,
#     'personId': 1628404,
#     'jerseyNum': '3',
#     'position': 'PF',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 6,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 4,
#      'fieldGoalsMade': 3,
#      'fieldGoalsPercentage': 0.75,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 75.0,
#      'minutes': 'PT32M37.02S',
#      'minutesCalculated': 'PT32M',
#      'plus': 91.0,
#      'plusMinusPoints': 16.0,
#      'points': 8,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 9,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 10,
#      'steals': 1,
#      'threePointersAttempted': 2,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.5,
#      'turnovers': 1,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 1.0},
#     'name': 'Josh Hart',
#     'nameI': 'J. Hart',
#     'firstName': 'Josh',
#     'familyName': 'Hart'},
#    {'status': 'ACTIVE',
#     'order': 3,
#     'personId': 1626157,
#     'jerseyNum': '32',
#     'position': 'C',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 1,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 12,
#      'fieldGoalsMade': 8,
#      'fieldGoalsPercentage': 0.666666666666666,
#      'foulsOffensive': 1,
#      'foulsDrawn': 4,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 9,
#      'freeThrowsMade': 8,
#      'freeThrowsPercentage': 0.888888888888889,
#      'minus': 61.0,
#      'minutes': 'PT28M45.98S',
#      'minutesCalculated': 'PT29M',
#      'plus': 79.0,
#      'plusMinusPoints': 18.0,
#      'points': 28,
#      'pointsFastBreak': 3,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 6,
#      'reboundsDefensive': 8,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 9,
#      'steals': 0,
#      'threePointersAttempted': 6,
#      'threePointersMade': 4,
#      'threePointersPercentage': 0.666666666666666,
#      'turnovers': 1,
#      'twoPointersAttempted': 6,
#      'twoPointersMade': 4,
#      'twoPointersPercentage': 0.666666666666666},
#     'name': 'Karl-Anthony Towns',
#     'nameI': 'K. Towns',
#     'firstName': 'Karl-Anthony',
#     'familyName': 'Towns'},
#    {'status': 'ACTIVE',
#     'order': 4,
#     'personId': 1628969,
#     'jerseyNum': '25',
#     'position': 'SG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 4,
#      'blocks': 2,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 15,
#      'fieldGoalsMade': 7,
#      'fieldGoalsPercentage': 0.466666666666667,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 88.0,
#      'minutes': 'PT36M23.00S',
#      'minutesCalculated': 'PT36M',
#      'plus': 90.0,
#      'plusMinusPoints': 2.0,
#      'points': 14,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 14,
#      'pointsSecondChance': 2,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 4,
#      'steals': 1,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 2,
#      'twoPointersAttempted': 14,
#      'twoPointersMade': 7,
#      'twoPointersPercentage': 0.5},
#     'name': 'Mikal Bridges',
#     'nameI': 'M. Bridges',
#     'firstName': 'Mikal',
#     'familyName': 'Bridges'},
#    {'status': 'ACTIVE',
#     'order': 5,
#     'personId': 1628973,
#     'jerseyNum': '11',
#     'position': 'PG',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 5,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 18,
#      'fieldGoalsMade': 12,
#      'fieldGoalsPercentage': 0.666666666666666,
#      'foulsOffensive': 1,
#      'foulsDrawn': 6,
#      'foulsPersonal': 5,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 8,
#      'freeThrowsMade': 7,
#      'freeThrowsPercentage': 0.875,
#      'minus': 72.0,
#      'minutes': 'PT27M54.98S',
#      'minutesCalculated': 'PT28M',
#      'plus': 71.0,
#      'plusMinusPoints': -1.0,
#      'points': 31,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 16,
#      'pointsSecondChance': 4,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 3,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 4,
#      'twoPointersAttempted': 15,
#      'twoPointersMade': 12,
#      'twoPointersPercentage': 0.8},
#     'name': 'Jalen Brunson',
#     'nameI': 'J. Brunson',
#     'firstName': 'Jalen',
#     'familyName': 'Brunson'},
#    {'status': 'ACTIVE',
#     'order': 6,
#     'personId': 1629011,
#     'jerseyNum': '23',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 1,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 1,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 1.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 37.0,
#      'minutes': 'PT18M18.01S',
#      'minutesCalculated': 'PT18M',
#      'plus': 51.0,
#      'plusMinusPoints': 14.0,
#      'points': 2,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 4,
#      'reboundsOffensive': 4,
#      'reboundsTotal': 8,
#      'steals': 1,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 1,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 1.0},
#     'name': 'Mitchell Robinson',
#     'nameI': 'M. Robinson',
#     'firstName': 'Mitchell',
#     'familyName': 'Robinson'},
#    {'status': 'ACTIVE',
#     'order': 7,
#     'personId': 1630540,
#     'jerseyNum': '2',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 1,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 6,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 5,
#      'freeThrowsMade': 4,
#      'freeThrowsPercentage': 0.8,
#      'minus': 44.0,
#      'minutes': 'PT23M42.00S',
#      'minutesCalculated': 'PT24M',
#      'plus': 69.0,
#      'plusMinusPoints': 25.0,
#      'points': 9,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 3,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 2,
#      'steals': 0,
#      'threePointersAttempted': 3,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.333333333333333,
#      'turnovers': 0,
#      'twoPointersAttempted': 3,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 0.333333333333333},
#     'name': 'Miles McBride',
#     'nameI': 'M. McBride',
#     'firstName': 'Miles',
#     'familyName': 'McBride'},
#    {'status': 'ACTIVE',
#     'order': 8,
#     'personId': 1626166,
#     'jerseyNum': '1',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 1,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 7,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.28571428571428603,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 3,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 18.0,
#      'minutes': 'PT09M32.99S',
#      'minutesCalculated': 'PT09M',
#      'plus': 23.0,
#      'plusMinusPoints': 5.0,
#      'points': 6,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 5,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.4,
#      'turnovers': 0,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Cameron Payne',
#     'nameI': 'C. Payne',
#     'firstName': 'Cameron',
#     'familyName': 'Payne'},
#    {'status': 'ACTIVE',
#     'order': 9,
#     'personId': 1626153,
#     'jerseyNum': '0',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 2.0,
#      'minutes': 'PT00M26.01S',
#      'minutesCalculated': 'PT01M',
#      'plus': 0.0,
#      'plusMinusPoints': -2.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Delon Wright',
#     'nameI': 'D. Wright',
#     'firstName': 'Delon',
#     'familyName': 'Wright'},
#    {'status': 'ACTIVE',
#     'order': 10,
#     'personId': 1630173,
#     'jerseyNum': '5',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Precious Achiuwa',
#     'nameI': 'P. Achiuwa',
#     'firstName': 'Precious',
#     'familyName': 'Achiuwa'},
#    {'status': 'ACTIVE',
#     'order': 11,
#     'personId': 1642359,
#     'jerseyNum': '4',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Pacôme Dadiet',
#     'nameI': 'P. Dadiet',
#     'firstName': 'Pacôme',
#     'familyName': 'Dadiet'},
#    {'status': 'ACTIVE',
#     'order': 12,
#     'personId': 1630574,
#     'jerseyNum': '55',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Ariel Hukporti',
#     'nameI': 'A. Hukporti',
#     'firstName': 'Ariel',
#     'familyName': 'Hukporti'},
#    {'status': 'ACTIVE',
#     'order': 13,
#     'personId': 1642278,
#     'jerseyNum': '13',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Tyler Kolek',
#     'nameI': 'T. Kolek',
#     'firstName': 'Tyler',
#     'familyName': 'Kolek'},
#    {'status': 'ACTIVE',
#     'order': 14,
#     'personId': 1629013,
#     'jerseyNum': '44',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Landry Shamet',
#     'nameI': 'L. Shamet',
#     'firstName': 'Landry',
#     'familyName': 'Shamet'},
#    {'status': 'ACTIVE',
#     'order': 15,
#     'personId': 200782,
#     'jerseyNum': '17',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'P.J. Tucker',
#     'nameI': 'P. Tucker',
#     'firstName': 'P.J.',
#     'familyName': 'Tucker'}],
#   'statistics': {'assists': 22,
#    'assistsTurnoverRatio': 2.44444444444444,
#    'benchPoints': 17,
#    'biggestLead': 17,
#    'biggestLeadScore': '94-111',
#    'biggestScoringRun': 14,
#    'biggestScoringRunScore': '92-108',
#    'blocks': 7,
#    'blocksReceived': 2,
#    'fastBreakPointsAttempted': 11,
#    'fastBreakPointsMade': 2,
#    'fastBreakPointsPercentage': 0.18181818181818202,
#    'fieldGoalsAttempted': 74,
#    'fieldGoalsEffectiveAdjusted': 0.608108108108108,
#    'fieldGoalsMade': 40,
#    'fieldGoalsPercentage': 0.540540540540541,
#    'foulsOffensive': 2,
#    'foulsDrawn': 18,
#    'foulsPersonal': 19,
#    'foulsTeam': 17,
#    'foulsTechnical': 0,
#    'foulsTeamTechnical': 0,
#    'freeThrowsAttempted': 30,
#    'freeThrowsMade': 21,
#    'freeThrowsPercentage': 0.7,
#    'leadChanges': 7,
#    'minutes': 'PT207M50.00S',
#    'minutesCalculated': 'PT207M',
#    'points': 111,
#    'pointsAgainst': 94,
#    'pointsFastBreak': 5,
#    'pointsFromTurnovers': 4,
#    'pointsInThePaint': 50,
#    'pointsInThePaintAttempted': 36,
#    'pointsInThePaintMade': 25,
#    'pointsInThePaintPercentage': 0.694444444444444,
#    'pointsSecondChance': 15,
#    'reboundsDefensive': 29,
#    'reboundsOffensive': 8,
#    'reboundsPersonal': 37,
#    'reboundsTeam': 15,
#    'reboundsTeamDefensive': 4,
#    'reboundsTeamOffensive': 11,
#    'reboundsTotal': 52,
#    'secondChancePointsAttempted': 8,
#    'secondChancePointsMade': 5,
#    'secondChancePointsPercentage': 0.625,
#    'steals': 5,
#    'teamFieldGoalAttempts': 0,
#    'threePointersAttempted': 26,
#    'threePointersMade': 10,
#    'threePointersPercentage': 0.384615384615385,
#    'timeLeading': 'PT27M24.95S',
#    'timesTied': 5,
#    'trueShootingAttempts': 87.2,
#    'trueShootingPercentage': 0.636467889908257,
#    'turnovers': 9,
#    'turnoversTeam': 0,
#    'turnoversTotal': 9,
#    'twoPointersAttempted': 48,
#    'twoPointersMade': 30,
#    'twoPointersPercentage': 0.625}},
#  'awayTeam': {'teamId': 1610612754,
#   'teamName': 'Pacers',
#   'teamCity': 'Indiana',
#   'teamTricode': 'IND',
#   'score': 94,
#   'inBonus': '0',
#   'timeoutsRemaining': 1,
#   'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 34},
#    {'period': 2, 'periodType': 'REGULAR', 'score': 28},
#    {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#    {'period': 4, 'periodType': 'REGULAR', 'score': 7}],
#   'players': [{'status': 'ACTIVE',
#     'order': 1,
#     'personId': 1630174,
#     'jerseyNum': '23',
#     'position': 'SF',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 2,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 6,
#      'fieldGoalsMade': 3,
#      'fieldGoalsPercentage': 0.5,
#      'foulsOffensive': 0,
#      'foulsDrawn': 6,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 1.0,
#      'minus': 75.0,
#      'minutes': 'PT28M29.99S',
#      'minutesCalculated': 'PT28M',
#      'plus': 69.0,
#      'plusMinusPoints': -6.0,
#      'points': 10,
#      'pointsFastBreak': 2,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 3,
#      'threePointersMade': 2,
#      'threePointersPercentage': 0.666666666666666,
#      'turnovers': 0,
#      'twoPointersAttempted': 3,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 0.333333333333333},
#     'name': 'Aaron Nesmith',
#     'nameI': 'A. Nesmith',
#     'firstName': 'Aaron',
#     'familyName': 'Nesmith'},
#    {'status': 'ACTIVE',
#     'order': 2,
#     'personId': 1627783,
#     'jerseyNum': '43',
#     'position': 'PF',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 4,
#      'blocks': 0,
#      'blocksReceived': 3,
#      'fieldGoalsAttempted': 15,
#      'fieldGoalsMade': 6,
#      'fieldGoalsPercentage': 0.4,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 3,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 0.666666666666666,
#      'minus': 88.0,
#      'minutes': 'PT31M18.00S',
#      'minutesCalculated': 'PT31M',
#      'plus': 76.0,
#      'plusMinusPoints': -12.0,
#      'points': 14,
#      'pointsFastBreak': 6,
#      'pointsInThePaint': 10,
#      'pointsSecondChance': 2,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 3,
#      'steals': 1,
#      'threePointersAttempted': 2,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 13,
#      'twoPointersMade': 6,
#      'twoPointersPercentage': 0.461538461538462},
#     'name': 'Pascal Siakam',
#     'nameI': 'P. Siakam',
#     'firstName': 'Pascal',
#     'familyName': 'Siakam'},
#    {'status': 'ACTIVE',
#     'order': 3,
#     'personId': 1626167,
#     'jerseyNum': '33',
#     'position': 'C',
#     'starter': '1',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 10,
#      'fieldGoalsMade': 6,
#      'fieldGoalsPercentage': 0.6,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 76.0,
#      'minutes': 'PT28M34.00S',
#      'minutesCalculated': 'PT29M',
#      'plus': 70.0,
#      'plusMinusPoints': -6.0,
#      'points': 14,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 5,
#      'steals': 1,
#      'threePointersAttempted': 4,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.25,
#      'turnovers': 1,
#      'twoPointersAttempted': 6,
#      'twoPointersMade': 5,
#      'twoPointersPercentage': 0.833333333333334},
#     'name': 'Myles Turner',
#     'nameI': 'M. Turner',
#     'firstName': 'Myles',
#     'familyName': 'Turner'},
#    {'status': 'ACTIVE',
#     'order': 4,
#     'personId': 1630169,
#     'jerseyNum': '0',
#     'position': 'SG',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 7,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 18,
#      'fieldGoalsMade': 9,
#      'fieldGoalsPercentage': 0.5,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 1.0,
#      'minus': 79.0,
#      'minutes': 'PT31M16.03S',
#      'minutesCalculated': 'PT31M',
#      'plus': 74.0,
#      'plusMinusPoints': -5.0,
#      'points': 23,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 5,
#      'reboundsDefensive': 3,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 3,
#      'steals': 1,
#      'threePointersAttempted': 10,
#      'threePointersMade': 3,
#      'threePointersPercentage': 0.3,
#      'turnovers': 1,
#      'twoPointersAttempted': 8,
#      'twoPointersMade': 6,
#      'twoPointersPercentage': 0.75},
#     'name': 'Tyrese Haliburton',
#     'nameI': 'T. Haliburton',
#     'firstName': 'Tyrese',
#     'familyName': 'Haliburton'},
#    {'status': 'ACTIVE',
#     'order': 5,
#     'personId': 1629614,
#     'jerseyNum': '2',
#     'position': 'PG',
#     'starter': '1',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 3,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 5,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.4,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 4,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 1,
#      'freeThrowsPercentage': 0.5,
#      'minus': 72.0,
#      'minutes': 'PT28M15.00S',
#      'minutesCalculated': 'PT28M',
#      'plus': 64.0,
#      'plusMinusPoints': -8.0,
#      'points': 6,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 2,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 4,
#      'steals': 0,
#      'threePointersAttempted': 2,
#      'threePointersMade': 1,
#      'threePointersPercentage': 0.5,
#      'turnovers': 2,
#      'twoPointersAttempted': 3,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 0.333333333333333},
#     'name': 'Andrew Nembhard',
#     'nameI': 'A. Nembhard',
#     'firstName': 'Andrew',
#     'familyName': 'Nembhard'},
#    {'status': 'ACTIVE',
#     'order': 6,
#     'personId': 1631097,
#     'jerseyNum': '00',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 5,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.4,
#      'foulsOffensive': 0,
#      'foulsDrawn': 3,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 5,
#      'freeThrowsMade': 5,
#      'freeThrowsPercentage': 1.0,
#      'minus': 57.0,
#      'minutes': 'PT21M07.98S',
#      'minutesCalculated': 'PT21M',
#      'plus': 43.0,
#      'plusMinusPoints': -14.0,
#      'points': 9,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 5,
#      'reboundsDefensive': 1,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 3,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 4,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 0.5},
#     'name': 'Bennedict Mathurin',
#     'nameI': 'B. Mathurin',
#     'firstName': 'Bennedict',
#     'familyName': 'Mathurin'},
#    {'status': 'ACTIVE',
#     'order': 7,
#     'personId': 1630167,
#     'jerseyNum': '1',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 6,
#      'fieldGoalsMade': 2,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 31.0,
#      'minutes': 'PT13M37.01S',
#      'minutesCalculated': 'PT14M',
#      'plus': 26.0,
#      'plusMinusPoints': -5.0,
#      'points': 4,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 4,
#      'pointsSecondChance': 2,
#      'reboundsDefensive': 6,
#      'reboundsOffensive': 2,
#      'reboundsTotal': 8,
#      'steals': 0,
#      'threePointersAttempted': 2,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 4,
#      'twoPointersMade': 2,
#      'twoPointersPercentage': 0.5},
#     'name': 'Obi Toppin',
#     'nameI': 'O. Toppin',
#     'firstName': 'Obi',
#     'familyName': 'Toppin'},
#    {'status': 'ACTIVE',
#     'order': 8,
#     'personId': 1628418,
#     'jerseyNum': '3',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 3,
#      'fieldGoalsMade': 1,
#      'fieldGoalsPercentage': 0.333333333333333,
#      'foulsOffensive': 0,
#      'foulsDrawn': 1,
#      'foulsPersonal': 1,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 2,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 1.0,
#      'minus': 30.0,
#      'minutes': 'PT10M11.99S',
#      'minutesCalculated': 'PT10M',
#      'plus': 16.0,
#      'plusMinusPoints': -14.0,
#      'points': 4,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 2,
#      'pointsSecondChance': 2,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 1,
#      'reboundsTotal': 1,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 2,
#      'twoPointersMade': 1,
#      'twoPointersPercentage': 0.5},
#     'name': 'Thomas Bryant',
#     'nameI': 'T. Bryant',
#     'firstName': 'Thomas',
#     'familyName': 'Bryant'},
#    {'status': 'ACTIVE',
#     'order': 9,
#     'personId': 204456,
#     'jerseyNum': '9',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '1',
#     'statistics': {'assists': 2,
#      'blocks': 0,
#      'blocksReceived': 1,
#      'fieldGoalsAttempted': 9,
#      'fieldGoalsMade': 4,
#      'fieldGoalsPercentage': 0.444444444444444,
#      'foulsOffensive': 0,
#      'foulsDrawn': 2,
#      'foulsPersonal': 2,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 4,
#      'freeThrowsMade': 2,
#      'freeThrowsPercentage': 0.5,
#      'minus': 44.0,
#      'minutes': 'PT14M04.00S',
#      'minutesCalculated': 'PT14M',
#      'plus': 30.0,
#      'plusMinusPoints': -14.0,
#      'points': 10,
#      'pointsFastBreak': 2,
#      'pointsInThePaint': 8,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 4,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 4,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 1,
#      'twoPointersAttempted': 8,
#      'twoPointersMade': 4,
#      'twoPointersPercentage': 0.5},
#     'name': 'T.J. McConnell',
#     'nameI': 'T. McConnell',
#     'firstName': 'T.J.',
#     'familyName': 'McConnell'},
#    {'status': 'ACTIVE',
#     'order': 10,
#     'personId': 1641767,
#     'jerseyNum': '26',
#     'starter': '0',
#     'oncourt': '1',
#     'played': '1',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 1,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 3.0,
#      'minutes': 'PT00M56.00S',
#      'minutesCalculated': 'PT01M',
#      'plus': 2.0,
#      'plusMinusPoints': -1.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 1,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Ben Sheppard',
#     'nameI': 'B. Sheppard',
#     'firstName': 'Ben',
#     'familyName': 'Sheppard'},
#    {'status': 'ACTIVE',
#     'order': 11,
#     'personId': 1628396,
#     'jerseyNum': '13',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Tony Bradley',
#     'nameI': 'T. Bradley',
#     'firstName': 'Tony',
#     'familyName': 'Bradley'},
#    {'status': 'ACTIVE',
#     'order': 12,
#     'personId': 1642277,
#     'jerseyNum': '12',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Johnny Furphy',
#     'nameI': 'J. Furphy',
#     'firstName': 'Johnny',
#     'familyName': 'Furphy'},
#    {'status': 'ACTIVE',
#     'notPlayingReason': 'DND_INJURY',
#     'notPlayingDescription': 'Right Achilles Tendon; Tear',
#     'order': 13,
#     'personId': 1630543,
#     'jerseyNum': '22',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Isaiah Jackson',
#     'nameI': 'I. Jackson',
#     'firstName': 'Isaiah',
#     'familyName': 'Jackson'},
#    {'status': 'ACTIVE',
#     'order': 14,
#     'personId': 201949,
#     'jerseyNum': '16',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'James Johnson',
#     'nameI': 'J. Johnson',
#     'firstName': 'James',
#     'familyName': 'Johnson'},
#    {'status': 'ACTIVE',
#     'order': 15,
#     'personId': 1641716,
#     'jerseyNum': '5',
#     'starter': '0',
#     'oncourt': '0',
#     'played': '0',
#     'statistics': {'assists': 0,
#      'blocks': 0,
#      'blocksReceived': 0,
#      'fieldGoalsAttempted': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalsPercentage': 0.0,
#      'foulsOffensive': 0,
#      'foulsDrawn': 0,
#      'foulsPersonal': 0,
#      'foulsTechnical': 0,
#      'freeThrowsAttempted': 0,
#      'freeThrowsMade': 0,
#      'freeThrowsPercentage': 0.0,
#      'minus': 0.0,
#      'minutes': 'PT00M00.00S',
#      'minutesCalculated': 'PT00M',
#      'plus': 0.0,
#      'plusMinusPoints': 0.0,
#      'points': 0,
#      'pointsFastBreak': 0,
#      'pointsInThePaint': 0,
#      'pointsSecondChance': 0,
#      'reboundsDefensive': 0,
#      'reboundsOffensive': 0,
#      'reboundsTotal': 0,
#      'steals': 0,
#      'threePointersAttempted': 0,
#      'threePointersMade': 0,
#      'threePointersPercentage': 0.0,
#      'turnovers': 0,
#      'twoPointersAttempted': 0,
#      'twoPointersMade': 0,
#      'twoPointersPercentage': 0.0},
#     'name': 'Jarace Walker',
#     'nameI': 'J. Walker',
#     'firstName': 'Jarace',
#     'familyName': 'Walker'}],
#   'statistics': {'assists': 18,
#    'assistsTurnoverRatio': 3.6,
#    'benchPoints': 27,
#    'biggestLead': 7,
#    'biggestLeadScore': '16-9',
#    'biggestScoringRun': 12,
#    'biggestScoringRunScore': '92-106',
#    'blocks': 2,
#    'blocksReceived': 7,
#    'fastBreakPointsAttempted': 6,
#    'fastBreakPointsMade': 4,
#    'fastBreakPointsPercentage': 0.666666666666666,
#    'fieldGoalsAttempted': 78,
#    'fieldGoalsEffectiveAdjusted': 0.493589743589744,
#    'fieldGoalsMade': 35,
#    'fieldGoalsPercentage': 0.44871794871794896,
#    'foulsOffensive': 0,
#    'foulsDrawn': 19,
#    'foulsPersonal': 18,
#    'foulsTeam': 18,
#    'foulsTechnical': 0,
#    'foulsTeamTechnical': 0,
#    'freeThrowsAttempted': 22,
#    'freeThrowsMade': 17,
#    'freeThrowsPercentage': 0.7727272727272729,
#    'leadChanges': 7,
#    'minutes': 'PT207M50.00S',
#    'minutesCalculated': 'PT207M',
#    'points': 94,
#    'pointsAgainst': 111,
#    'pointsFastBreak': 10,
#    'pointsFromTurnovers': 18,
#    'pointsInThePaint': 38,
#    'pointsInThePaintAttempted': 36,
#    'pointsInThePaintMade': 19,
#    'pointsInThePaintPercentage': 0.527777777777778,
#    'pointsSecondChance': 16,
#    'reboundsDefensive': 22,
#    'reboundsOffensive': 10,
#    'reboundsPersonal': 32,
#    'reboundsTeam': 7,
#    'reboundsTeamDefensive': 2,
#    'reboundsTeamOffensive': 5,
#    'reboundsTotal': 39,
#    'secondChancePointsAttempted': 9,
#    'secondChancePointsMade': 5,
#    'secondChancePointsPercentage': 0.555555555555556,
#    'steals': 3,
#    'teamFieldGoalAttempts': 0,
#    'threePointersAttempted': 27,
#    'threePointersMade': 7,
#    'threePointersPercentage': 0.25925925925925897,
#    'timeLeading': 'PT12M31.05S',
#    'timesTied': 5,
#    'trueShootingAttempts': 87.68,
#    'trueShootingPercentage': 0.536040145985401,
#    'turnovers': 5,
#    'turnoversTeam': 0,
#    'turnoversTotal': 5,
#    'twoPointersAttempted': 51,
#    'twoPointersMade': 28,
#    'twoPointersPercentage': 0.549019607843137}}}
